# %% [markdown]
# Utkarsh Gaikwad
# Aim-
#
# 1) Provide summery statistics for a dataset with numeric varibles grouped by one
# of the qualitative variables
# 2) write a python program to display some basic statistical details like percentile,mean,standard deviation,etc.

# %% [markdown]
# Import Required Libraries

# %%
import pandas as pd

# %% [markdown]
# Loading the Dataset

# %%
df=pd.read_csv('Mall_Customers-Ass3_dataset.csv')

# %%
df
# Out:
#      CustomerID   Genre  Age  Income   Score
# 0             1    Male   19       15      39
# 1             2    Male   21       15      81
# 2             3  Female   20       16       6
# 3             4  Female   23       16      77
# 4             5  Female   31       17      40
# ..          ...     ...  ...      ...     ...
# 195         196  Female   35      120      79
# 196         197  Female   45      126      28
# 197         198    Male   32      126      74
# 198         199    Male   32      137      18
# 199         200    Male   30      137      83
#
# [200 rows x 5 columns]

# %% [markdown]
# Returns mean value

# %%
df.mean()
# Out:
# <ipython-input-7-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# CustomerID    100.50
# Age            38.85
# Income         60.56
# Score          50.20
# dtype: float64

# %% [markdown]
# Returns Median Value

# %%
df.median()
# Out:
# <ipython-input-8-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# CustomerID    100.5
# Age            36.0
# Income         61.5
# Score          50.0
# dtype: float64

# %% [markdown]
# Standard Deviation

# %%
df.std()
# Out:
# <ipython-input-9-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# CustomerID    57.879185
# Age           13.969007
# Income        26.264721
# Score         25.823522
# dtype: float64

# %% [markdown]
# Returns Minimum value

# %%
df.min()
# Out:
# CustomerID         1
# Genre         Female
# Age               18
# Income            15
# Score              1
# dtype: object

# %% [markdown]
# Returns Maximum Value

# %%
df.max()
# Out:
# CustomerID     200
# Genre         Male
# Age             70
# Income         137
# Score           99
# dtype: object

# %% [markdown]
# Importing Numpy Library

# %%
import numpy as np

# %% [markdown]
# calculating the standard deviation

# %%
df.std()
# Out:
# <ipython-input-13-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# CustomerID    57.879185
# Age           13.969007
# Income        26.264721
# Score         25.823522
# dtype: float64

# %% [markdown]
# Create grouping using Genre

# %%
gr1 = df.groupby('Genre')

# %% [markdown]
# Using get_group

# %%
m = gr1.get_group("Male")

# %%
m
# Out:
#      CustomerID Genre  Age  Income   Score
# 0             1  Male   19       15      39
# 1             2  Male   21       15      81
# 8             9  Male   64       19       3
# 10           11  Male   67       19      14
# 14           15  Male   37       20      13
# ..          ...   ...  ...      ...     ...
# 187         188  Male   28      101      68
# 192         193  Male   33      113       8
# 197         198  Male   32      126      74
# 198         199  Male   32      137      18
# 199         200  Male   30      137      83
#
# [88 rows x 5 columns]

# %% [markdown]
# Describe Grouping values

# %%
m.describe()
# Out:
#        CustomerID        Age     Income      Score
# count   88.000000  88.000000   88.000000  88.000000
# mean   104.238636  39.806818   62.227273  48.511364
# std     57.483830  15.514812   26.638373  27.896770
# min      1.000000  18.000000   15.000000   1.000000
# 25%     59.500000  27.750000   45.500000  24.500000
# 50%    106.500000  37.000000   62.500000  50.000000
# 75%    151.250000  50.500000   78.000000  70.000000
# max    200.000000  70.000000  137.000000  97.000000

# %% [markdown]
# Construct DataFrame from group with Female

# %%
f = gr1.get_group("Female")

# %%
f
# Out:
#      CustomerID   Genre  Age  Income   Score
# 2             3  Female   20       16       6
# 3             4  Female   23       16      77
# 4             5  Female   31       17      40
# 5             6  Female   22       17      76
# 6             7  Female   35       18       6
# ..          ...     ...  ...      ...     ...
# 191         192  Female   32      103      69
# 193         194  Female   38      113      91
# 194         195  Female   47      120      16
# 195         196  Female   35      120      79
# 196         197  Female   45      126      28
#
# [112 rows x 5 columns]

# %%
f.describe()
# Out:
#        CustomerID         Age     Income       Score
# count  112.000000  112.000000  112.000000  112.000000
# mean    97.562500   38.098214   59.250000   51.526786
# std     58.276412   12.644095   26.011952   24.114950
# min      3.000000   18.000000   16.000000    5.000000
# 25%     46.750000   29.000000   39.750000   35.000000
# 50%     94.500000   35.000000   60.000000   50.000000
# 75%    148.250000   47.500000   77.250000   73.000000
# max    197.000000   68.000000  126.000000   99.000000

# %% [markdown]
#  groupby function in pandas that allows you to group data based on a single column or more

# %%
gr2 = df.groupby('Age')

# %%
gr2.groups
# Out:
# {18: [33, 65, 91, 114], 19: [0, 61, 68, 111, 113, 115, 138, 162], 20: [2, 17, 39, 99, 134], 21: [1, 31, 35, 84, 105], 22: [5, 15, 87], 23: [3, 7, 29, 78, 100, 124], 24: [13, 41, 45, 95], 25: [21, 132, 144], 26: [75, 103], 27: [47, 58, 97, 120, 155, 177], 28: [142, 145, 171, 187], 29: [25, 48, 135, 161, 183], 30: [9, 37, 157, 159, 175, 185, 199], 31: [4, 23, 43, 49, 52, 125, 133, 163], 32: [69, 94, 137, 141, 143, 147, 169, 181, 191, 197, 198], 33: [51, 167, 192], 34: [88, 148, 149, 158, 190], 35: [6, 11, 16, 19, 20, 27, 139, 179, 195], 36: [38, 165, 168, 172, 173, 189], 37: [14, 156, 180], 38: [81, 112, 121, 129, 153, 193], 39: [123, 131, 151], 40: [28, 77, 93, 122, 127, 170], 41: [184, 188], 42: [36, 166], 43: [66, 126, 150], 44: [136, 152], 45: [26, 76, 196], 46: [22, 83, 182], 47: [55, 71, 96, 130, 154, 194], 48: [42, 85, 92, 98, 146], 49: [34, 44, 50, 79, 101, 104, 117], 50: [46, 54, 89, 119, 164], 51: [56, 118], 52: [18, 174], 53: [32, 59], 54: [24, 63, 107, 186], 55: [86], 56: [
# ...

# %%
m1 = gr2.get_group(20)

# %% [markdown]
# Importing Seaborn Library

# %%
import seaborn as sns

# %% [markdown]
# Loading the dataset

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Creates data based on species

# %%
gr = df.groupby('species')

# %% [markdown]
# Construct DataFrame grouping for setosa and virginica

# %%
ve = gr.get_group('setosa')
vi = gr.get_group('virginica')

# %% [markdown]
# shape - enables us to obtain the shape of a DataFrame

# %%
ve.shape
# Out:
# (50, 5)

# %%
vi.shape
# Out:
# (50, 5)

# %%
ve.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000
